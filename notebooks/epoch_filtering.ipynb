# %%
import mne
import numpy as np

from mushroom_hyperscanning.epochs import (
    extract_coherent_epochs,
    find_epoch_intersection,
    plot_epoch_distribution,
)

# %%
ceremony = "ceremony1"
root = "../data/temp_004_autoreject"
window_length = 5.0

# %%
chunks1, chunks3 = find_epoch_intersection(
    extract_coherent_epochs(1, ceremony, root, window_length=window_length),
    extract_coherent_epochs(3, ceremony, root, window_length=window_length),
)

# %%
plot_epoch_distribution(chunks1)
plot_epoch_distribution(chunks3)
